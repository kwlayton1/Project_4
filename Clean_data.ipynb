# %%
# import the dependencies

import pandas as pd

# %%
dataset=pd.read_csv("Resources/column_2C_weka.csv")
dataset.head()
# Out:
#    pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt numeric       310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 17.1+ KB

# %%
dataset.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt numeric', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis', 'class'],
#       dtype='object')

# %%
dataset=dataset.rename(columns={"pelvic_incidence":"Pelvic Incidence",
                                "pelvic_tilt numeric":"Pelvic Tilt",
                                "lumbar_lordosis_angle":"Lumbar Lordosis Angle",
                                "sacral_slope":"Sacral Slope",
                                "pelvic_radius":"Pelvic Radius",
                                "degree_spondylolisthesis":"Grade of spondylolisthesis",
                                "class":"Results"})
dataset.head()
# Out:
#    Pelvic Incidence  Pelvic Tilt  Lumbar Lordosis Angle  Sacral Slope  \
# 0             63.03    22.552586              39.609117     40.475232
# 1             39.06    10.060991              25.015378     28.995960
# 2             68.83    22.218482              50.092194     46.613539
# 3             69.30    24.652878              44.311238     44.644130
# 4             49.71     9.652075              28.317406     40.060784
#
#    Pelvic Radius  Grade of spondylolisthesis   Results
# 0      98.672917                   -0.254400  Abnormal
# 1     114.405425                    4.564259  Abnormal
# 2     105.985135                   -3.530317  Abnormal
# 3     101.868495                   11.211523  Abnormal
# 4     108.168725                    7.918501  Abnormal

# %%
dataset["Pelvic Incidence"]=round(dataset["Pelvic Incidence"],2)
dataset.head()
# Out:
#    Pelvic Incidence  Pelvic Tilt  Lumbar Lordosis Angle  Sacral Slope  \
# 0             63.03    22.552586              39.609117     40.475232
# 1             39.06    10.060991              25.015378     28.995960
# 2             68.83    22.218482              50.092194     46.613539
# 3             69.30    24.652878              44.311238     44.644130
# 4             49.71     9.652075              28.317406     40.060784
#
#    Pelvic Radius  Grade of spondylolisthesis   Results
# 0      98.672917                   -0.254400  Abnormal
# 1     114.405425                    4.564259  Abnormal
# 2     105.985135                   -3.530317  Abnormal
# 3     101.868495                   11.211523  Abnormal
# 4     108.168725                    7.918501  Abnormal

# %%
dataset["Pelvic Tilt"]=round(dataset["Pelvic Tilt"],2)
dataset["Lumbar Lordosis Angle"]=round(dataset["Lumbar Lordosis Angle"],2)
dataset["Sacral Slope"]=round(dataset["Sacral Slope"],2)
dataset["Pelvic Radius"]=round(dataset["Pelvic Radius"],2)
dataset["Grade of spondylolisthesis"]=round(dataset["Grade of spondylolisthesis"],2)
dataset.head()
# Out:
#    Pelvic Incidence  Pelvic Tilt  Lumbar Lordosis Angle  Sacral Slope  \
# 0             63.03        22.55                  39.61         40.48
# 1             39.06        10.06                  25.02         29.00
# 2             68.83        22.22                  50.09         46.61
# 3             69.30        24.65                  44.31         44.64
# 4             49.71         9.65                  28.32         40.06
#
#    Pelvic Radius  Grade of spondylolisthesis   Results
# 0          98.67                       -0.25  Abnormal
# 1         114.41                        4.56  Abnormal
# 2         105.99                       -3.53  Abnormal
# 3         101.87                       11.21  Abnormal
# 4         108.17                        7.92  Abnormal

# %%
dataset.to_csv("Resources/dataset_clean.csv",index=False)

# %%
dataset.describe()
# Out:
#        Pelvic Incidence  Pelvic Tilt  Lumbar Lordosis Angle  Sacral Slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496484    17.542903              51.930710     42.953871
# std           17.236109    10.008140              18.553766     13.422748
# min           26.150000    -6.550000              14.000000     13.370000
# 25%           46.432500    10.667500              37.000000     33.347500
# 50%           58.690000    16.360000              49.565000     42.405000
# 75%           72.880000    22.120000              63.000000     52.692500
# max          129.830000    49.430000             125.740000    121.430000
#
#        Pelvic Radius  Grade of spondylolisthesis
# count     310.000000                  310.000000
# mean      117.920548                   26.296742
# std        13.317629                   37.558883
# min        70.080000                  -11.060000
# 25%       110.710000                    1.600000
# ...
